# %%
import pandas as pd

# %%
df = pd.read_csv("cities.csv")

# %%
df
# Out:
#      City ID          City Country  Cloudiness        Date  Humidity      Lat  \
# 0          0     kushmurun      KZ          98  1632243372        67  52.4503
# 1          1  saint george      US           0  1632243323        19  37.1041
# 2          2        kodiak      US           0  1632243372        51  57.7900
# 3          3   port alfred      ZA          98  1632243373        69 -33.5906
# 4          4         bluff      NZ          35  1632243373        73 -46.6000
# ..       ...           ...     ...         ...         ...       ...      ...
# 543      543        sukumo      JP          70  1632243647        96  32.9333
# 544      544   deputatskiy      RU         100  1632243394        74  69.3000
# 545      545   bronnoysund      NO          75  1632243648        82  65.4625
# 546      546           bud      US          95  1632243649        86  39.4470
# 547      547        wanaka      NZ          63  1632243513        88 -44.7000
#
# ...

# %%
df.set_index('City ID', inplace=True)
df
# Out:
#                  City Country  Cloudiness        Date  Humidity      Lat  \
# City ID
# 0           kushmurun      KZ          98  1632243372        67  52.4503
# 1        saint george      US           0  1632243323        19  37.1041
# 2              kodiak      US           0  1632243372        51  57.7900
# 3         port alfred      ZA          98  1632243373        69 -33.5906
# 4               bluff      NZ          35  1632243373        73 -46.6000
# ...               ...     ...         ...         ...       ...      ...
# 543            sukumo      JP          70  1632243647        96  32.9333
# 544       deputatskiy      RU         100  1632243394        74  69.3000
# 545       bronnoysund      NO          75  1632243648        82  65.4625
# 546               bud      US          95  1632243649        86  39.4470
# 547            wanaka      NZ          63  1632243513        88 -44.7000
#
#               Lng  Max Temp  Wind Speed
# City ID
# ...

# %%
df.to_html("cities.html")
